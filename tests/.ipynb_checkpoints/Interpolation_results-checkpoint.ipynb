# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('interpolation_test.csv')
df.head(20)
# Out:
#     Profile_id  Down-sampling Interpolation  Down-sampling dx       MSE
# 0            0              2        linear          0.600601  0.000359
# 1            0              2    polinomial          0.600601  0.000115
# 2            0              3        linear          0.900901  0.001334
# 3            0              3    polinomial          0.900901  0.000819
# 4            0              4        linear          1.201201  0.002619
# 5            0              4    polinomial          1.201201  0.003042
# 6            0              5        linear          1.501502  0.005051
# 7            0              5    polinomial          1.501502  0.006902
# 8            1              2        linear          0.600601  0.000314
# 9            1              2    polinomial          0.600601  0.000108
# 10           1              3        linear          0.900901  0.001446
# 11           1              3    polinomial          0.900901  0.000964
# 12           1              4        linear          1.201201  0.002680
# 13           1              4    polinomial          1.201201  0.002344
# 14           1              5        linear          1.501502  0.005250
# 15           1              5    polinomial          1.501502  0.006008
# 16           2              2        linear          0.600601  0.000321
# 17           2              2    polinomial          0.600601  0.000118
# 18           2              3        linear          0.900901  0.001125
# 19           2              3    polinomial          0.900901  0.000728

# %%
linear = []
polinomial = []
x = []

for i in np.unique(df['Down-sampling']):
    x.append(i)
    linear.append(np.mean(df.loc[df['Interpolation'] == 'linear'].loc[df['Down-sampling'] == i]['MSE']))
    polinomial.append(np.mean(df.loc[df['Interpolation'] == 'polinomial'].loc[df['Down-sampling'] == i]['MSE']))

# %%
plt.plot(x, linear, 'o', label = 'linear interpolation')
plt.plot(x, polinomial, 'o', label = 'polinomal interpolation')
plt.xticks(x)
plt.ylabel('MSE')
plt.xlabel('Down-sampling rate')
plt.legend()
plt.show()

# %%
xd = np.unique(df['Down-sampling dx'])
plt.plot(xd, linear, 'o', label = 'linear interpolation')
plt.plot(xd, polinomial, 'o', label = 'polinomal interpolation')
plt.xticks(xd)
plt.ylabel('MSE')
plt.xlabel('Down-sampling distance')
plt.legend()
plt.show()
